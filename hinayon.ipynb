# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv('dataset.csv')

# %%
data = pd.read_csv('dataset.csv')
data.head()
# Out:
#   General_Health Exercise Depression Diabetes     Sex Age_Category  \
# 0           Poor       No         No       No  Female        70-74
# 1      Very Good       No         No      Yes  Female        70-74
# 2      Very Good      Yes         No      Yes  Female        60-64
# 3           Poor      Yes         No      Yes    Male        75-79
# 4           Good       No         No       No    Male          80+
#
#    Weight_(kg)    BMI Smoking_History Alcohol_Consumption Heart_Disease
# 0        32.66  14.54             Yes                  No            No
# 1        77.11  28.29              No                  No           Yes
# 2        88.45  33.47              No                  No            No
# 3        93.44  28.73              No                 Yes           Yes
# 4        88.45  24.37             Yes                 Yes            No

# %%
data.describe().T
# Out:
#              count       mean        std    min    25%    50%    75%     max
# Weight_(kg)  999.0  80.999409  19.803497  32.66  67.59  79.38  91.17  167.83
# BMI          999.0  28.560350   6.221840  14.06  24.21  27.78  31.89   51.81

# %%
# data1 = data.drop(columns=['Cancer Stage', 'Survival Rate (5-Year, %)'])

# %%
n_data = data.dropna()

# %%
print("DataFrame:\n", n_data.head())

# Feature to analyze
feature = 'Age_Category'

# Display unique categories
categories = n_data[feature].unique()
print(f"\nUnique categories in '{feature}':\n", categories)
# Out:
# DataFrame:
#    General_Health Exercise Depression Diabetes     Sex Age_Category  \
# 0           Poor       No         No       No  Female        70-74
# 1      Very Good       No         No      Yes  Female        70-74
# 2      Very Good      Yes         No      Yes  Female        60-64
# 3           Poor      Yes         No      Yes    Male        75-79
# 4           Good       No         No       No    Male          80+
#
#    Weight_(kg)    BMI Smoking_History Alcohol_Consumption Heart_Disease
# 0        32.66  14.54             Yes                  No            No
# 1        77.11  28.29              No                  No           Yes
# 2        88.45  33.47              No                  No            No
# 3        93.44  28.73              No                 Yes           Yes
# 4        88.45  24.37             Yes                 Yes            No
#
# Unique categories in 'Age_Category':
#  ['70-74' '60-64' '75-79' '80+' '65-69' '50-54' '45-49' '18-24' '30-34'
# ...

# %%
n_data.describe().T
# Out:
#              count       mean        std    min    25%    50%    75%     max
# Weight_(kg)  999.0  80.999409  19.803497  32.66  67.59  79.38  91.17  167.83
# BMI          999.0  28.560350   6.221840  14.06  24.21  27.78  31.89   51.81

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns

# grouped_data = n_data['hospital_death'].value_counts()

# grouped_data = grouped_data.sort_index()




# fig, ax = plt.subplots(figsize=(16, 10), dpi=80)
# sns.barplot(x=grouped_data.index, y=grouped_data.values, ax=ax, palette="muted")

# ax.set_title("hospital_death  vs. No hospital_death", size=20)
# ax.set_xlabel("hospital_death", size=20)
# ax.set_ylabel("Average No. of  hospital_death", size=20)

# plt.show()

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns
# import pandas as pd

# grouped_data = n_data.groupby(['elective_surgery', 'hospital_death']).size().unstack(fill_value=0)

# fig, ax = plt.subplots(figsize=(16, 10), dpi=80)

# grouped_data.plot(kind='area', stacked=True, colormap='viridis', alpha=0.7, ax=ax)

# ax.set_title("Elective Surgery vs. Hospital Death (Stacked Area Chart)", size=20)
# ax.set_xlabel("Elective Surgery", size=20)
# ax.set_ylabel("Patient Count", size=20)

# plt.legend(title="Hospital Death", labels=["Survived", "Died"])
# plt.show()

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns

# features = ['elective_surgery', 'hospital_death', 'age', 'bmi', 'ethnicity']

# sns.pairplot(n_data[features], hue='hospital_death', palette="husl", diag_kind='kde')

# plt.suptitle("Pairplot of Patient Features", size=20, y=1.02)
# plt.show()

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns
# import pandas as pd

# # Selecting relevant numerical features
# features = ['elective_surgery', 'hospital_death', 'age', 'bmi', 'lymphoma']

# # Compute the correlation matrix
# corr_matrix = n_data[features].corr()

# # Create a heatmap
# plt.figure(figsize=(10, 6), dpi=80)
# sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5, vmin=-1, vmax=1)

# # Labels and title
# plt.title("Correlation Heatmap of Patient Features", size=18)
# plt.show()

# %%
# import matplotlib.pyplot as plt
# import pandas as pd
# import seaborn as sns
# from pandas.plotting import parallel_coordinates

# features = ['elective_surgery', 'hospital_death', 'age', 'bmi', 'lymphoma']
# df = n_data[features].copy()

# df[features] = (df[features] - df[features].min()) / (df[features].max() - df[features].min())

# df['hospital_death'] = df['hospital_death'].astype(str)

# plt.figure(figsize=(12, 6), dpi=80)
# parallel_coordinates(df, class_column='hospital_death', colormap=plt.get_cmap("coolwarm"), alpha=0.7)

# plt.title("Parallel Coordinates Plot of Patient Features", size=18)
# plt.xlabel("Features", size=14)
# plt.ylabel("Normalized Values", size=14)
# plt.xticks(rotation=45)
# plt.legend(title="Hospital Death", labels=["Survived", "Died"])
# plt.grid(True)

# plt.show()

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns

# plt.figure(figsize=(12, 6), dpi=80)

# sns.violinplot(x="elective_surgery", y="age", hue="hospital_death", data=n_data, split=True, palette="coolwarm")

# plt.title("Age Distribution by Elective Surgery and Hospital Death", size=18)
# plt.xlabel("Elective Surgery", size=14)
# plt.ylabel("Age", size=14)
# plt.legend(title="Hospital Death", labels=["Survived", "Died"])

# plt.show()

# %%
# import numpy as np
# import matplotlib.pyplot as plt

# features = ['elective_surgery', 'hospital_death', 'age', 'bmi', 'lymphoma']
# avg_values = n_data[features].mean().values 

# min_vals = n_data[features].min().values
# max_vals = n_data[features].max().values
# normalized_values = (avg_values - min_vals) / (max_vals - min_vals)

# angles = np.linspace(0, 2 * np.pi, len(features), endpoint=False).tolist()
# normalized_values = np.concatenate((normalized_values, [normalized_values[0]]))  
# angles += angles[:1]  

# fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))
# ax.fill(angles, normalized_values, color='blue', alpha=0.4, label="Average Values")
# ax.plot(angles, normalized_values, color='blue', linewidth=2)  

# ax.set_xticks(angles[:-1])
# ax.set_xticklabels(features, fontsize=12)

# plt.title("Radar Chart of Patient Features", size=16)
# plt.legend(loc="upper right")
# plt.show()

# %%
import pandas as pd

# Example data
n_data2 = n_data

# Convert 'Heart_Disease' to binary
n_data2['Heart_Disease'] = [1 if x == 'Yes' else 0 for x in n_data2['Heart_Disease']]

# Round off BMI and Weight_(kg) to the nearest whole number and convert to integers
n_data3 = n_data2.copy()
n_data3['BMI'] = n_data3['BMI'].round(0).astype(int)
n_data3['Weight_(kg)'] = n_data3['Weight_(kg)'].round(0).astype(int)

# %%
x = n_data3.drop(columns=['Heart_Disease']
                )

y = n_data3['Heart_Disease']

# %% [markdown]
# Encoding Process

# %%
categorical_columns = data.select_dtypes(include=['object', 'category']).columns
print(categorical_columns)
# Out:
# Index(['General_Health', 'Exercise', 'Depression', 'Diabetes', 'Sex',
#        'Age_Category', 'Smoking_History', 'Alcohol_Consumption',
#        'Heart_Disease'],
#       dtype='object')

# %%
from category_encoders import BinaryEncoder
import pandas as pd

categorical_features = ['General_Health', 'Exercise', 'Depression', 'Diabetes', 'Sex',
       'Age_Category', 'Smoking_History', 'Alcohol_Consumption']
      
encoder = BinaryEncoder()
x_encoded = encoder.fit_transform(x[categorical_features])
x = x.drop(categorical_features, axis=1)
x = x.reset_index(drop=True)
x_encoded = x_encoded.reset_index(drop=True)
x = pd.concat([x, x_encoded], axis=1)

# 'Age','Tumor Size (cm)','Cancer Stage','Survival Rate (5-Year, %)','Cost of Treatment (USD)', 'Economic Burden (Lost Workdays per Year)',
#                         'Country_0','Country_1','Country_2','Country_3','Country_4','Gender_0','Gender_1','Tobacco Use_0','Tobacco Use_1','Alcohol Consumption_1',
#                         'HPV Infection_0','HPV Infection_0','Betel Quid Use_0','Betel Quid Use_0','Gender_0'

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.25,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
dcs = DecisionTreeClassifier()
dcs.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
prediction = dcs.predict(x_test)

# %%
from sklearn.metrics import(
    accuracy_score,
    precision_score
)
prediction = dcs.predict(x_test)
accuracy = accuracy_score (prediction,y_test)
precision = precision_score (prediction, y_test)


print(f"accuracy: {accuracy*100}")
print(f"precision: {precision*100}")
# Out:
# accuracy: 78.4
# precision: 24.324324324324326

# %%
n_prediction = dcs.predict(x_test.iloc[[70]])

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE()
x, y = smote.fit_resample (x,y)

# %%
x_train1,x_test1,y_train1,y_test1 = train_test_split(x,y,test_size=.25,random_state=42)

# %%
dcs1 = DecisionTreeClassifier()
dcs1.fit(x_train1, y_train1)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.metrics import accuracy_score, precision_score

dcs_prediction = dcs1.predict(x_test1)

dcs_accuracy = accuracy_score(y_test1, dcs_prediction)
dcs_precision = precision_score(y_test1, dcs_prediction)

print(f"accuracy: {dcs_accuracy*100}")
print(f"precision: {dcs_precision*100}")
# Out:
# accuracy: 87.64568764568764
# precision: 86.7579908675799

# %%
y.value_counts()
# Out:
# Heart_Disease
# 0    858
# 1    858
# Name: count, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier, export_graphviz
import graphviz
from joblib import dump, load
import joblib

dsc1 = DecisionTreeClassifier()
dsc1.fit(x_train1, y_train1)

export_graphviz(dsc1, out_file="tree.dot", filled=True, feature_names=x_train1.columns)

with open("tree.dot") as f:
    dot_graph = f.read()
    graph = graphviz.Source(dot_graph)
    graph.view()  

dump(dsc1, "decision_tree_model.joblib")
# Out:
# ['decision_tree_model.joblib']

# %%
loaded_model = load ("decision_tree_model.joblib")
loaded_prediction = loaded_model.predict (x_test1)
